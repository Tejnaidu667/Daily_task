# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejnaidu667/Daily_task/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num=float(input("enter a number: "))
if num>0:
  print("positive")
elif num==0:
  print("not +ve or -ve")
else:
  print("negative")
# Out:
# enter a number: 7
# positive
