# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejnaidu667/Daily_task/blob/main/larvalue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
s=[2,3,10,7,3,8]
ans=0
for i in range(len(s)):
    temp=0
    if (s[i])>=ans:
        ans=s[i]
print(ans)
# Out:
# 10

# %% [markdown]
# a function that returns the largest number in a list.
